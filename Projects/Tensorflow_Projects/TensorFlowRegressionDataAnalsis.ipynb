# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housedata=pd.read_csv('../TensorFlow_EX/TensorFlow_FILES/DATA/kc_house_data.csv')
housedata.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
housedata.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
housedata.isnull().sum() # we cant see any null if its there then we could remove it
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.distplot(housedata['price'])
#sns.set_theme('default')
# Out:
# C:\Users\karuppasamy.v\AppData\Local\Temp\ipykernel_14556\193340525.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housedata['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.countplot(data=housedata,x='bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
# here we will fetch  the lat and lon values

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(housedata,x='price',y='lat')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(housedata,x='price',y='long')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(housedata,x='long',y='lat',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
# here i will sort the values based on the price then ASC is false 
housedata.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(housedata)*0.01
# Out:
# 215.97

# %%
#now we will create new data frame thats not containing top 1 per values

new_top_per=housedata.sort_values('price',ascending=False).iloc[216:]
new_top_per
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',data=new_top_per,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(housedata,x='long',y='lat',hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
housedata
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
#when want to extract the date as date or month or day then the column should be an date object
#housedata=housedata.drop('id',axis=1)
housedata.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
housedata['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
housedata['date']=pd.to_datetime(housedata['date'])

# %%
# we are now just spliting the year and month
housedata['year']=housedata['date'].apply(lambda year_v:year_v.year)
housedata['Month']=housedata['date'].apply(lambda year_v:year_v.month)
housedata['Day']=housedata['date'].apply(lambda year_v:year_v.day)

# %%
housedata.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year  Month  Day
# ...

# %%
#you should create the plot based on the month

housedata.groupby('Month').mean()['price'].plot()
# Out:
# C:\Users\karuppasamy.v\AppData\Local\Temp\ipykernel_14556\1185792488.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   housedata.groupby('Month').mean()['price'].plot()
# <Axes: xlabel='Month'>

# %%
#take every month of the mean and create the plot

# %%
housedata.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year  Month  Day
# ...

# %%
housedata=housedata.drop('date',axis=1)

# %%
housedata.head(5)
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
housedata.zipcode.value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
housedata.sqft_basement.value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
housedata.yr_renovated.value_counts().head()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
# Name: yr_renovated, dtype: int64

# %%
housedata.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'Month', 'Day'],
#       dtype='object')

# %%
X=housedata.drop('price',axis=1).values
y=housedata['price'].values

# %%
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
# here we are just tranforming the train data and test data using MinMaxScaler Object 

X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %% [markdown]
# # here we are going to perfomr tensorflow keras model

# %%
#here we are import  the sequential using the keras model using tensorflow
# then also importing the dense using the layers using tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape # here below we could see 22 thats the neauron layer
# Out:
# (15117, 22)

# %%
#we will create the object of the sequential
#and also now we will train our data also adding dense layerr

# %%
model=Sequential()
model.add(Dense(22,activation='relu'))
model.add(Dense(22,activation='relu'))
model.add(Dense(22,activation='relu'))
model.add(Dense(22,activation='relu'))

#final one of adding the dense layer
model.add(Dense(1))


model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# # now we will fit our data model which means we will train our data as well as validate also

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),
         batch_size=128,epochs=400) # here beloe we trained our data
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 6ms/step - loss: 430216085504.0000 - val_loss: 418794373120.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 427329355776.0000 - val_loss: 409200001024.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 5ms/step - loss: 387871375360.0000 - val_loss: 325937823744.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 235813748736.0000 - val_loss: 143593897984.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 114203254784.0000 - val_loss: 103374356480.0000
# Epoch 6/400
# 119/119 [==============================] - 1s 5ms/step - loss: 104639496192.0000 - val_loss: 101347295232.0000
# Epoch 7/400
# 119/119 [==============================] - 1s 5ms/step - loss: 102430072832.0000 - val_loss: 99179347968.0000
# Epoch 8/400
# ...

# %% [markdown]
# # if we want to see loss of our model data you could use history to get that will return to the dict

# %%
model.history.history
# Out:
# {'loss': [430216085504.0,
#   427329355776.0,
#   387871375360.0,
#   235813748736.0,
#   114203254784.0,
#   104639496192.0,
#   102430072832.0,
#   100225359872.0,
#   97905197056.0,
#   95466348544.0,
#   92908191744.0,
#   90158718976.0,
#   87215464448.0,
#   84013604864.0,
#   80658522112.0,
#   77085933568.0,
#   73329541120.0,
#   69486534656.0,
#   65733537792.0,
#   62151282688.0,
#   59051126784.0,
#   56417935360.0,
#   54327463936.0,
#   52648353792.0,
#   51246841856.0,
#   50010472448.0,
#   48899796992.0,
#   47909605376.0,
#   47002365952.0,
#   46175469568.0,
#   45351419904.0,
#   44663939072.0,
#   43911987200.0,
#   43220017152.0,
#   42602246144.0,
#   41958391808.0,
#   41419563008.0,
#   40848101376.0,
#   40352571392.0,
#   39821512704.0,
#   39366979584.0,
#   38982897664.0,
#   38535069696.0,
#   38171918336.0,
#   37850198016.0,
#   37469134848.0,
#   37276655616.0,
#   36954013696.0,
#   36666368000.0,
#   36391723008.0,
#   36156940288.0,
# ...

# %%
pd.DataFrame(model.history.history) #In below we could see the loss as well as the val_loss also that is our test_data loss
# we can see the loss on trainig as well loss on testing
# Out:
#              loss      val_loss
# 0    4.302161e+11  4.187944e+11
# 1    4.273294e+11  4.092000e+11
# 2    3.878714e+11  3.259378e+11
# 3    2.358137e+11  1.435939e+11
# 4    1.142033e+11  1.033744e+11
# ..            ...           ...
# 395  2.495648e+10  3.133753e+10
# 396  2.494758e+10  3.200108e+10
# 397  2.495729e+10  2.957464e+10
# 398  2.492545e+10  3.249826e+10
# 399  2.492731e+10  3.078733e+10
#
# [400 rows x 2 columns]

# %%
testndtrainloss=pd.DataFrame(model.history.history)
testndtrainloss.plot()
# Out:
# <Axes: >

# %% [markdown]
# # we will find the mean absolute error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
prediction_price=model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
print(np.sqrt(mean_squared_error(y_test,prediction_price)))
# Out:
# 175463.18045376276

# %%
print(mean_absolute_error(y_test,prediction_price))
# Out:
# 109005.37057894483

# %% [markdown]
# # if we want to our meansolute error is correct or not then we can use mean absolute error

# %%
housedata['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05 #here we will get the value of the mean data
# Out:
# 540296.6

# %%
# Explained variance regression score function.

# Best possible score is 1.0, lower values are worse.

# %%
explained_variance_score(y_test,prediction_price)
# Out:
# 0.8010101599577306

# %%
Here i got .8 its ok normal we need to sill more training and reducing our loss data
# Out:
#   Cell In[70], line 1
#     Here i got .8 its ok normal we need to sill more training and reducing our loss data
#          ^
# SyntaxError: invalid syntax

# %%
#below fig we will get the correct prediction which means best or perfect prediction line

# %%
#here i will create the plot our prediction and our test data
sns.set_theme()
plt.figure(figsize=(10,5))
plt.scatter(y_test,prediction_price)
plt.plot(y_test,y_test,'r') # the red color line is the best prediction ever

# %%
# our prediction is not bad as well as also not good because 0 to 2laks price prediction is ok but not bad

# %%
#now we got the lots of loss based on the our prediction so that now we will take first data then predict the value
#see what happen if its predict right or wrong
#housedata.drop('id',axis=1,inplace=True)

# %%
housedata.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year  Month  Day
# ...

# %%
single_house_values=housedata.drop('price',axis=1).iloc[0]

# %%
single_house_values
# Out:
# id               7.129301e+09
# bedrooms         3.000000e+00
# bathrooms        1.000000e+00
# sqft_living      1.180000e+03
# sqft_lot         5.650000e+03
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        3.000000e+00
# grade            7.000000e+00
# sqft_above       1.180000e+03
# sqft_basement    0.000000e+00
# yr_built         1.955000e+03
# yr_renovated     0.000000e+00
# zipcode          9.817800e+04
# lat              4.751120e+01
# long            -1.222570e+02
# sqft_living15    1.340000e+03
# sqft_lot15       5.650000e+03
# year             2.014000e+03
# Month            1.000000e+01
# Day              1.300000e+01
# Name: 0, dtype: float64

# %%
single_house_values=scaler.transform(single_house_values.values.reshape(-1,22))

# %%
single_house_values
# Out:
# array([[0.72010308, 0.0625    , 0.06666667, 0.05792683, 0.00516884,
#         0.        , 0.        , 0.        , 0.5       , 0.33333333,
#         0.08453838, 0.        , 0.47826087, 0.        , 0.89393939,
#         0.56720299, 0.215     , 0.13926499, 0.00574235, 0.        ,
#         0.81818182, 0.4       ]])

# %%
singlehousepredict=model.predict(single_house_values)
singlehousepredict
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[247479.23]], dtype=float32)

# %%
housedata.head(2)
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
#
#       long  sqft_living15  sqft_lot15  year  Month  Day
# 0 -122.257           1340        5650  2014     10   13
# 1 -122.319           1690        7639  2014     12    9
#
# [2 rows x 23 columns]

# %%
#2nd house prediction

sec_house_val=housedata.drop('price',axis=1).iloc[1]

# %%
sec_house_val=scaler.transform(sec_house_val.values.reshape(-1,22))

# %%
model.predict(sec_house_val)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[487809.25]], dtype=float32)

# %%
#this is also prediction is wrong
# Out:
# array([[0.64785332, 0.0625    , 0.23333333, 0.16387195, 0.00678932,
#         0.4       , 0.        , 0.        , 0.5       , 0.33333333,
#         0.19466073, 0.0968523 , 0.44347826, 0.98808933, 0.62626263,
#         0.90817487, 0.16333333, 0.20696325, 0.00802712, 0.        ,
#         1.        , 0.26666667]])
