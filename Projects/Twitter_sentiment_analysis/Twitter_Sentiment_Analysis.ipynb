# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import nltk

# %%
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopwords
# ...
#         C:\Users\karuppasamy.v\AppData\Roaming\nltk_data...
#       Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

# %%
from WordCloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from WordCloud import WordCloud,STOPWORDS
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'WordCloud'

# %%
twitdata=pd.read_csv('Sentiment.csv')
twitdata.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# ...

# %%
twitdata[['text','sentiment']]
# Out:
#                                                     text sentiment
# 0      RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2      RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
# [13871 rows x 2 columns]

# %%
train,test = train_test_split(twitdata, test_size=0.3)

# %%
#removing th neutral data
train=train[train.sentiment!='Neutral']

# %%
train.head()
# Out:
#           id               candidate  candidate_confidence relevant_yn  \
# 13097  13098                Jeb Bush                1.0000         yes
# 5556    5557            Donald Trump                0.3779         yes
# 8962    8963            Donald Trump                1.0000         yes
# 10488  10489            Donald Trump                1.0000         yes
# 4230    4231  No candidate mentioned                1.0000         yes
#
#        relevant_yn_confidence sentiment  sentiment_confidence  \
# 13097                  1.0000  Negative                1.0000
# 5556                   0.6147  Negative                0.6147
# 8962                   1.0000  Positive                0.6786
# 10488                  1.0000  Negative                0.6984
# 4230                   1.0000  Negative                0.6277
#
#                subject_matter  subject_matter_confidence candidate_gold  ...  \
# 13097       None of the above                     1.0000            NaN  ...
# ...

# %%
train_neg_text=train[ train['sentiment'] == 'Positive']
train_neg_text=train_neg_text['text']
train_neg_text.head()
# Out:
# 8962     RT @ProfessorRobo: To start th evening, RNC mo...
# 8318     RT @Lrihendry: #TedCruz As President, I will a...
# 11600    RT @RWSurferGirl: Ask Trump a legitimate quest...
# 10489    Many good men in 2nd GOP debates #GOPDebate #G...
# 1418     This #GOPDebate is keeping the spray tan indus...
# Name: text, dtype: object

# %%
train_pos_text=train[ train['sentiment'] == 'Positive']
train_pos_text=train_pos_text['text']
train_pos_text.head()
# Out:
# 8962     RT @ProfessorRobo: To start th evening, RNC mo...
# 8318     RT @Lrihendry: #TedCruz As President, I will a...
# 11600    RT @RWSurferGirl: Ask Trump a legitimate quest...
# 10489    Many good men in 2nd GOP debates #GOPDebate #G...
# 1418     This #GOPDebate is keeping the spray tan indus...
# Name: text, dtype: object

# %%
def textjoin(wordstr):
    wordjoin=' '.join(wordstr)
    return ' '.join([word for word in wordjoin.split()
                    if 'http' not in word
                    and not word.startswith('@')
                    and not word.startswith('#')
                    and word!='RT'
                    if word.lower() not in stopwords.words('english')
                    ])

# %%
print(textjoin(train_Neg_text))
# Out:
# Jeb Bush reminds elevator music. hear listen. 🇺🇸 lie Mr. Speaker that's like DONT BELIEVE FACTS DONALD TRUMP DISS’ DA RICAN many mentions fetuses, almost mentions people carry them. Rand Paul looked woefully underprepared. came armed zingers attitude, respond comebacks. "Kill people break things," Huckabee described GOP. showed -they watched last night? heard funniest thing since - accuracy mind blowing... indeed good source laughter concern. call Bush interview? smart Kasich say, essentially, "I hear concerns Trump voters except I'm sane" “Mr. Trump, next question you. Please explain pathetic taking Stone Cold Stunner” htt… past 10 years, U.S. military endured suicide epidemic among troops; 2/3 deaths involved guns need good bad egg chute...to weed politicians...boos cutting it. person problem -Trump issues women respect women Donald Trumps attack Megyn Kelly prove point woman problem. Unless like attacks them. Lol conservatives trolling tryna start argument God men worship money. d
# ...

# %%
print(len(textjoin(train_Neg_text)))
# Out:
# 480122

# %%
print(len(textjoin(train_Neg_text)))
# Out:
# 342173

# %%
print(len(textjoin(train_Neg_text)))
# Out:
# 342173

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
twitdata['t'].head()
# Out:
# 0    2015-08-07 09:54:46 -0700
# 1    2015-08-07 09:54:46 -0700
# 2    2015-08-07 09:54:46 -0700
# 3    2015-08-07 09:54:45 -0700
# 4    2015-08-07 09:54:45 -0700
# Name: tweet_created, dtype: object

# %%
from nltk.tokenize
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> L
#
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
# ...
